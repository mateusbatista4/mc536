# %% [markdown]
# # Tarefa 1
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import requests
import json
import pandas as pd
import io

# %%
#JSON DATA

uri = 'https://disease.sh/v3/covid-19/countries/'

req = requests.get(uri)
data = json.loads(req.content)
table = pd.json_normalize(data)
table.head(10)
# Out:
#          updated  ...                            countryInfo.flag
# 0  1629924606970  ...  https://disease.sh/assets/img/flags/af.png
# 1  1629924606978  ...  https://disease.sh/assets/img/flags/al.png
# 2  1629924606966  ...  https://disease.sh/assets/img/flags/dz.png
# 3  1629924607192  ...  https://disease.sh/assets/img/flags/ad.png
# 4  1629924607082  ...  https://disease.sh/assets/img/flags/ao.png
# 5  1629924607393  ...  https://disease.sh/assets/img/flags/ai.png
# 6  1629924607385  ...  https://disease.sh/assets/img/flags/ag.png
# 7  1629924606585  ...  https://disease.sh/assets/img/flags/ar.png
# 8  1629924606961  ...  https://disease.sh/assets/img/flags/am.png
# 9  1629924607261  ...  https://disease.sh/assets/img/flags/aw.png
#
# [10 rows x 28 columns]

# %%
#CSV DATA
]
uri2 = 'https://www.quandl.com/api/v3/datasets/WIKI/QCOM.csv'

req = requests.get(uri2)
csv = pd.read_csv(io.StringIO(req.content.decode("utf-8")))
print(csv)
# Out:
#             Date   Open   High  ...   Adj. Low  Adj. Close  Adj. Volume
# 0     2018-03-27  56.59  57.24  ...  54.540000   54.840000   11972935.0
# 1     2018-03-26  54.58  56.14  ...  54.250000   56.130000   11905323.0
# 2     2018-03-23  55.63  56.15  ...  53.650000   53.660000   14509870.0
# 3     2018-03-22  56.24  56.83  ...  55.520000   55.580000   13218154.0
# 4     2018-03-21  57.50  58.28  ...  56.770000   56.810000   12122169.0
# ...          ...    ...    ...  ...        ...         ...          ...
# 6613  1991-12-20  17.50  18.25  ...   0.417172    0.429091    5235200.0
# 6614  1991-12-19  18.25  18.25  ...   0.417172    0.417172    7299200.0
# 6615  1991-12-18  17.75  18.25  ...   0.423131    0.435050   10899200.0
# 6616  1991-12-17  18.50  18.50  ...   0.417172    0.423131   16176000.0
# 6617  1991-12-16  16.75  19.00  ...   0.399293    0.429091  143667200.0
#
# [6618 rows x 13 columns]

# %% [markdown]
# #Tarefa 2
# ##Engenharia reversa
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama

# %% [markdown]
# As Imagens dos diagramas encontram-se na pasta "imagens".
